# %%
! pip install scikit-learn

# %%
# Import packages
import numpy as np
import pandas as pd

from google.colab import files
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelBinarizer

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b4b94ac9-af07-4baa-91b5-1b45d02c7cfe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4b94ac9-af07-4baa-91b5-1b45d02c7cfe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## To Get understanding of the inflation interst unemployment dataset

# %%
# Assume the uploaded file has a name 'your_file.csv'
df = pd.read_csv('inflation interest unemployment.csv')

# %%
df.head()
# Out:
#        country  year  Inflation, consumer prices (annual %)  \
# 0  Afghanistan  1970                                    NaN
# 1  Afghanistan  1971                                    NaN
# 2  Afghanistan  1972                                    NaN
# 3  Afghanistan  1973                                    NaN
# 4  Afghanistan  1974                                    NaN
#
#    Inflation, GDP deflator (annual %)  Real interest rate (%)  \
# 0                                 NaN                     NaN
# 1                                 NaN                     NaN
# 2                                 NaN                     NaN
# 3                                 NaN                     NaN
# 4                                 NaN                     NaN
#
#    Deposit interest rate (%)  Lending interest rate (%)  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# ...

# %%
df.describe(include="all")
# Out:
#             country          year  Inflation, consumer prices (annual %)  \
# count         13832  13832.000000                            9582.000000
# unique          266           NaN                                    NaN
# top     Afghanistan           NaN                                    NaN
# freq             52           NaN                                    NaN
# mean            NaN   1995.500000                              21.554734
# std             NaN     15.008874                             308.738258
# min             NaN   1970.000000                             -18.108630
# 25%             NaN   1982.750000                               2.462827
# 50%             NaN   1995.500000                               5.128995
# 75%             NaN   2008.250000                              10.095799
# max             NaN   2021.000000                           23773.131774
#
#         Inflation, GDP deflator (annual %)  Real interest rate (%)  \
# ...

# %% [markdown]
# ## For Singapore DATA only

# %%
# To filter only for Singapore Data
#Replace 'Singapore' for 'United States' for US Data, change graph accordingly

filtered_df = df[df['country'] == 'Singapore']
filtered_df
# Out:
#          country  year  Inflation, consumer prices (annual %)  \
# 11024  Singapore  1970                               0.463353
# 11025  Singapore  1971                               1.761006
# 11026  Singapore  1972                               2.080758
# 11027  Singapore  1973                              19.636731
# 11028  Singapore  1974                              22.368421
# 11029  Singapore  1975                               2.536532
# 11030  Singapore  1976                              -1.841893
# 11031  Singapore  1977                               3.163950
# 11032  Singapore  1978                               4.872544
# 11033  Singapore  1979                               4.076465
# 11034  Singapore  1980                               8.526943
# 11035  Singapore  1981                               8.182022
# 11036  Singapore  1982                               3.916287
# 11037  Singapore  1983                               1.196411
# ...

# %%
# Replace NaN values with the mean of the column
filtered_df['Inflation, GDP deflator (annual %)'] = filtered_df['Inflation, GDP deflator (annual %)'].fillna(filtered_df['Inflation, GDP deflator (annual %)'].mean())
# Out:
# <ipython-input-16-1dd3d4e73838>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Inflation, GDP deflator (annual %)'] = filtered_df['Inflation, GDP deflator (annual %)'].fillna(filtered_df['Inflation, GDP deflator (annual %)'].mean())

# %%
# Plotting the time series for inflation, GDP deflator (annual %)
plt.figure(figsize=(10,6))
plt.plot(filtered_df['year'], filtered_df['Inflation, GDP deflator (annual %)'], marker='o', linestyle='-', color='b')
plt.title('Inflation (GDP deflator) in Singapore Over Time (Till 2021)')
plt.xlabel('Year')
plt.ylabel('Inflation, GDP deflator (annual %)')
plt.grid(True)
plt.show()

# %%
# Plotting the time series for Inflation,
plt.figure(figsize=(10,6))
plt.plot(filtered_df['year'], filtered_df['Inflation, consumer prices (annual %)'], marker='o', linestyle='-', color='g')
plt.title('Inflation (Consumer Prices) in Singapore Over Time (Till 2021)')
plt.xlabel('Year')
plt.ylabel('Inflation, consumer prices (annual %)')
plt.grid(True)
plt.show()

# %%
# For missing data in the unemployment column
filtered_df['Unemployment, total (% of total labor force) (national estimate)'] = filtered_df['Unemployment, total (% of total labor force) (national estimate)'].fillna(filtered_df['Unemployment, total (% of total labor force) (national estimate)'].mean())
# Out:
# <ipython-input-19-995b6637af54>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Unemployment, total (% of total labor force) (national estimate)'] = filtered_df['Unemployment, total (% of total labor force) (national estimate)'].fillna(filtered_df['Unemployment, total (% of total labor force) (national estimate)'].mean())

# %%
plt.figure(figsize=(10,6))
plt.plot(filtered_df['year'], filtered_df['Unemployment, total (% of total labor force) (national estimate)'], marker='o', linestyle='-', color='b')
plt.title('Unemployment Rate (National Estimate) Over Time in Singapore (Till 2021)')
plt.xlabel('Year')
plt.ylabel('Unemployment, total (% of total labor force)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## For United State Data

# %%
filtered_df_us = df[df['country'] == 'United States']
filtered_df_us
# Out:
#              country  year  Inflation, consumer prices (annual %)  \
# 13156  United States  1970                               5.838255
# 13157  United States  1971                               4.292767
# 13158  United States  1972                               3.272278
# 13159  United States  1973                               6.177760
# 13160  United States  1974                              11.054805
# 13161  United States  1975                               9.143147
# 13162  United States  1976                               5.744813
# 13163  United States  1977                               6.501684
# 13164  United States  1978                               7.630964
# 13165  United States  1979                              11.254471
# 13166  United States  1980                              13.549202
# 13167  United States  1981                              10.334715
# 13168  United States  1982                               6.131427
# ...

# %%
# Replace NaN values with the mean of the column
filtered_df_us['Inflation, GDP deflator (annual %)'] = filtered_df_us['Inflation, GDP deflator (annual %)'].fillna(filtered_df_us['Inflation, GDP deflator (annual %)'].mean())
# Out:
# <ipython-input-8-aeda3ea67bc7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_us['Inflation, GDP deflator (annual %)'] = filtered_df_us['Inflation, GDP deflator (annual %)'].fillna(filtered_df_us['Inflation, GDP deflator (annual %)'].mean())

# %%
# Plotting the time series for inflation, GDP deflator (annual %)
plt.figure(figsize=(10,6))
plt.plot(filtered_df_us['year'], filtered_df_us['Inflation, GDP deflator (annual %)'], marker='o', linestyle='-', color='b')
plt.title('Inflation (GDP deflator) in United State Over Time (Till 2021)')
plt.xlabel('Year')
plt.ylabel('Inflation, GDP deflator (annual %)')
plt.grid(True)
plt.show()

# %%
# Plotting the time series for Inflation,
plt.figure(figsize=(10,6))
plt.plot(filtered_df_us['year'], filtered_df_us['Inflation, consumer prices (annual %)'], marker='o', linestyle='-', color='g')
plt.title('Inflation (Consumer Prices) in United State Over Time (Till 2021)')
plt.xlabel('Year')
plt.ylabel('Inflation, consumer prices (annual %)')
plt.grid(True)
plt.show()

# %%
# For missing data in the unemployment column
filtered_df_us['Unemployment, total (% of total labor force) (national estimate)'] = filtered_df_us['Unemployment, total (% of total labor force) (national estimate)'].fillna(filtered_df_us['Unemployment, total (% of total labor force) (national estimate)'].mean())
# Out:
# <ipython-input-12-b166a094bb85>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_us['Unemployment, total (% of total labor force) (national estimate)'] = filtered_df_us['Unemployment, total (% of total labor force) (national estimate)'].fillna(filtered_df_us['Unemployment, total (% of total labor force) (national estimate)'].mean())

# %%
plt.figure(figsize=(10,6))
plt.plot(filtered_df_us['year'], filtered_df_us['Unemployment, total (% of total labor force) (national estimate)'], marker='o', linestyle='-', color='b')
plt.title('Unemployment Rate (National Estimate) Over Time in United State (Till 2021)')
plt.xlabel('Year')
plt.ylabel('Unemployment, total (% of total labor force)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Side by Side Comparison

# %%
# Create a figure with 1 row and 2 columns
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# First plot (United States)
axes[0].plot(filtered_df_us['year'], filtered_df_us['Unemployment, total (% of total labor force) (national estimate)'], marker='o', linestyle='-', color='b')
axes[0].set_title('Unemployment Rate (National Estimate) Over Time in United States (Till 2021)')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Unemployment, total (% of total labor force)')
axes[0].grid(True)

# Second plot (Singapore)
axes[1].plot(filtered_df['year'], filtered_df['Unemployment, total (% of total labor force) (national estimate)'], marker='o', linestyle='-', color='g')
axes[1].set_title('Unemployment Rate (National Estimate) Over Time in Singapore (Till 2021)')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Unemployment, total (% of total labor force)')
axes[1].grid(True)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Create a figure with 1 row and 2 columns
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# First plot: Inflation (Consumer Prices) in the United States
axes[0].plot(filtered_df_us['year'], filtered_df_us['Inflation, consumer prices (annual %)'], marker='o', linestyle='-', color='b')
axes[0].set_title('Inflation (Consumer Prices) in United States Over Time (Till 2021)')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Inflation, consumer prices (annual %)')
axes[0].grid(True)

# Second plot: Inflation (Consumer Prices) in Singapore
axes[1].plot(filtered_df['year'], filtered_df['Inflation, consumer prices (annual %)'], marker='o', linestyle='-', color='g')
axes[1].set_title('Inflation (Consumer Prices) in Singapore Over Time (Till 2021)')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Inflation, consumer prices (annual %)')
axes[1].grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
# Create a figure with 1 row and 2 columns
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# First plot: Inflation (GDP deflator) in the United States
axes[0].plot(filtered_df_us['year'], filtered_df_us['Inflation, GDP deflator (annual %)'], marker='o', linestyle='-', color='b')
axes[0].set_title('Inflation (GDP Deflator) in United States Over Time (Till 2021)')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Inflation, GDP deflator (annual %)')
axes[0].grid(True)

# Second plot: Inflation (GDP deflator) in Singapore
axes[1].plot(filtered_df['year'], filtered_df['Inflation, GDP deflator (annual %)'], marker='o', linestyle='-', color='g')
axes[1].set_title('Inflation (GDP Deflator) in Singapore Over Time (Till 2021)')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Inflation, GDP deflator (annual %)')
axes[1].grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
